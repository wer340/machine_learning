# %%
# !pip3 install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Read the first CSV file
df1 = pd.read_csv("snapp_Samples/snapp_db_Users.csv")

# Read the second CSV file
df2 = pd.read_csv("snapp_Samples/snapp_db_Orders.csv")

# Merge the two CSV files

# %%
df['cellphone'] = df['cellphone'].astype(str)

# فیلتر کردن شماره‌های تلفن با شروع از +989121
filtered_df = df[df['cellphone'].str.startswith('989121')]

# ذخیره نتایج در یک فایل CSV
filtered_df.to_csv('filtered_results.csv', index=False)

# نمایش نتایج
print(filtered_df)
# Out:
#            id  created_by  updated_by                      username  \
# 37    1372537   1361959.0  16324889.0                   09121836797
# 41    1199727    236095.0   3031371.0                   09121799179
# 67    4135512   4135512.0  13607977.0                   09121543370
# 68    1035642   1035642.0   1035642.0                   09121352865
# 70   16464444  16464444.0  16464444.0                     vmo296070
# ..        ...         ...         ...                           ...
# 911   2924548   1606559.0   4422468.0                   09121978252
# 913    317432    317432.0  11186057.0  reza.shahnazizadeg@gmail.com
# 937   1093433    511364.0   7507735.0                   09121931146
# 965    854064    317620.0  16612448.0                   09121038525
# 982   2766736    325883.0  15994423.0                   09121011579
#
#                                 salt                         email  \
# 37   kdj7k7ouda8w4ocsscgks44o8cskows             ba11549@yahoo.com
# ...

# %%
#delivery_address_phone1
df2['delivery_address_phone1'] = df2['delivery_address_phone1'].astype(str)

# فیلتر کردن شماره‌های تلفن با شروع از +989121
filtered_df = df2[df2['delivery_address_phone1'].str.startswith('989121')]

# ذخیره نتایج در یک فایل CSV
filtered_df.to_csv('filtered_results_order.csv', index=False)

# نمایش نتایج
print(filtered_df)
# Out:
#             id  vendor_id  customer_id  status_id  payment_type_id  bank_id  \
# 25   377222740     298164       184319        153                1      5.0
# 28   377222737      51866      3424478        153                1      4.0
# 60   377222705      83265      6749959        153                1      4.0
# 75   377222690     323419     21371740        128                1      4.0
# 126  377222639      28452      6248562        123                1     18.0
# 147  377222618      85288      7213000        123                1      4.0
# 329  377222434     294303      5693243        123                1      4.0
# 363  377222400     280146      1372537        123                1      4.0
# 409  377222354      25391      1199727        123                1      4.0
# 504  377222259      25391      1199727        128                1      4.0
# 515  377222248     350881     10522518        153                1      4.0
# ...
